# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\user\\Downloads\\results_test.csv')

# %%
df
# Out:
#    Unnamed: 0       40f      100f  354f377m
# 0        목뒤높이  0.011255  0.013588  0.010723
# 1       엉덩이높이  0.025709  0.026107  0.022976
# 2       겨드랑높이  0.010059  0.018216  0.009067
# 3        허리높이  0.015759  0.010634  0.014388
# 4         샅높이  0.014365  0.013681  0.014978
# 5        무릎높이  0.034727  0.030654  0.026128
# 6        머리둘레  0.016199  0.015727  0.013737
# 7         목둘레  0.032347  0.037645  0.032171
# 8       젖가슴둘레  0.025223  0.027699  0.026568
# 9        허리둘레  0.053564  0.049598  0.060277
# 10   배꼽수준허리둘레  0.042973  0.044999  0.045041
# 11      엉덩이둘레  0.018180  0.031149  0.028504
# 12      넙다리둘레  0.033852  0.035781  0.043137
# 13       무릎둘레  0.023058  0.010665  0.032614
# 14      장딴지둘레  0.038435  0.040475  0.040606
# 15    종아리최소둘레  0.037509  0.043045  0.044737
# 16       발목둘레  0.044452  0.041717  0.045945
# 17      편위팔둘레  0.039422  0.034906  0.036997
# 18     편팔꿈치둘레  0.032485  0.029886  0.036251
# 19       손목둘레  0.039207  0.028373  0.031723
# ...

# %%
df['40f']
# Out:
# 0     0.011255
# 1     0.025709
# 2     0.010059
# 3     0.015759
# 4     0.014365
# 5     0.034727
# 6     0.016199
# 7     0.032347
# 8     0.025223
# 9     0.053564
# 10    0.042973
# 11    0.018180
# 12    0.033852
# 13    0.023058
# 14    0.038435
# 15    0.037509
# 16    0.044452
# 17    0.039422
# 18    0.032485
# 19    0.039207
# 20    0.027473
# 21    0.023577
# 22    0.019617
# 23    0.041997
# 24    0.049217
# 25    0.032487
# 26    0.047318
# 27    0.056962
# 28    0.046769
# 29    0.050243
# 30    0.053695
# 31    0.033488
# Name: 40f, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(df['40f'], label='40f')
plt.plot(df['100f'], label='100f')
plt.plot(df['354f377m'], label='354f377m')
plt.legend()
plt.show()

# %%
df = pd.read_csv('C:\\Users\\user\\Downloads\\test_result_2.csv')

# %%
df
# Out:
#   Unnamed: 0      목뒤높이     엉덩이높이     겨드랑높이      허리높이       샅높이      무릎높이  \
# 0        40f  0.011255  0.025709  0.010059  0.015759  0.014365  0.034727
# 1       100f  0.013588  0.026107  0.018216  0.010634  0.013681  0.030654
# 2   354f377m  0.010723  0.022976  0.009067  0.014388  0.014978  0.026128
#
#        머리둘레       목둘레     젖가슴둘레  ...    머리수직길이    얼굴수직길이       발크기       발너비  \
# 0  0.016199  0.032347  0.025223  ...  0.041997  0.049217  0.032487  0.047318
# 1  0.015727  0.037645  0.027699  ...  0.045252  0.061583  0.045976  0.054403
# 2  0.013737  0.032171  0.026568  ...  0.051581  0.065880  0.044864  0.039047
#
#        얼굴너비     손직선길이   손바닥직선길이  손안쪽가쪽직선길이  Unnamed: 32       avg
# 0  0.056962  0.046769  0.050243   0.053695     0.033488  0.033488
# 1  0.034791  0.050655  0.040591   0.051852     0.034087  0.034087
# 2  0.033169  0.046823  0.042224   0.050299     0.034420  0.034420
#
# [3 rows x 34 columns]

# %%
df.plot.line()
# Out:
# C:\Users\user\anaconda3\envs\py375tf26g\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 47785 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\envs\py375tf26g\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 46244 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\envs\py375tf26g\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 45458 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\envs\py375tf26g\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\envs\py375tf26g\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 50633 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
